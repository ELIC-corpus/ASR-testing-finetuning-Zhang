# %%
# import all libraries

import glob
import re
import numpy as np
import pandas as pd
import os

# %%
# all the functions needed 

def get_df_from_textgrid(file, threshold): # change threshold as needed
    
    try:
        with open(file, 'r', encoding='utf-8') as f:
            lines = [line.rstrip() for line in f]
    except:
        with open(file, 'r', encoding = 'utf-16-be') as f:
            lines = [line.rstrip() for line in f]
    text_list = []
    xmin_list = []
    xmax_list = []
    interval_list = []
    layer_list = []
    layer = 1
    for line in lines[14:]:  #informations needed begin on the 9th lines
        if "item [" in line:
            # update layer number
            layer = layer + 1
        
        if 'text =' in line:
            line = line.split('"')[1]
            if line != "":
                text_list.append(line)
                layer_list.append(layer)
                #print (len(text_list), len(xmin_list), len(xmax_list), len(interval_list), line, interval_list[-2:], layer)
            else:
                xmin_list = xmin_list[:-1]
                xmax_list = xmax_list[:-1]
                interval_list = interval_list[:-1]
        if 'xmin' in line:
            time_min = line.split('=')[1].strip(' ')
            xmin_list.append(time_min)
        if 'xmax' in line:
            time_max = line.split('=')[1].strip(' ')
            xmax_list.append(time_max)
        if 'intervals [' in line:
            interval = line.split('[')[1].strip(']:')
            interval_list.append(interval)
        if 'intervals: size' in line:
            xmin_list = xmin_list[:-1]
            xmax_list = xmax_list[:-1]
    xmin_list = [float(item) for item in xmin_list]
    xmax_list = [float(item) for item in xmax_list]
    interval_list = [int(item) for item in interval_list]

    df = pd.DataFrame()
    df['text'] = text_list
    df['xmin'] = xmin_list
    df['xmax'] = xmax_list
    df['interval'] = interval_list
    df['layer'] = layer_list
    
    # keep layer 1 and 2
    df_sub = df[df['layer'].isin([1,2])]
    df_sub['overlap'] = df_sub.apply(lambda x: overlap_record(df_sub, x.layer, x.interval), axis = 1)
    df_sub['overlap_max'] = df_sub['overlap'].apply(lambda x: get_max_overlap_percent(x))
    df_sub_keep = df_sub[df_sub['overlap_max'] < threshold]
    
    return df_sub_keep

def overlap_judge(x1_min, x1_max, x2_min, x2_max):
    overlap_length = 0
    overlap_perc_x1 = 0
    overlap_perc_x2 = 0
    if x1_min <= x2_min:
        if x1_max > x2_min:
            overlap = 1
            overlap_length = min(x2_max, x1_max) - x2_min
        else:
            overlap = 0
    elif x1_min < x2_max:
        overlap = 1
        overlap_length = min(x2_max, x1_max) - x1_min
    elif x1_min >= x2_max:
        overlap = 0
    
    # get overlap percentage
    if overlap == 1:
        #print (overlap_length)
        overlap_perc_x1 = round(overlap_length / (x1_max - x1_min), 2)
        overlap_perc_x2 = round(overlap_length / (x2_max - x2_min), 2)
    return overlap, overlap_length, overlap_perc_x1, overlap_perc_x2


def overlap_record(df_sub, curr_layer, curr_interval):
    df = df_sub
    if curr_layer == 1:
        goal_layer = 2
    if curr_layer == 2:
        goal_layer = 1
    x1_min = df[(df['layer'] == curr_layer) & (df['interval'] == curr_interval)]['xmin'].tolist()[0]
    x1_max = df[(df['layer'] == curr_layer) & (df['interval'] == curr_interval)]['xmax'].tolist()[0]
    goal_layer_number = len(df[df['layer'] == goal_layer]) # number of intervals to be compared in total
    
    goal_interval_list = df[df['layer'] == goal_layer]['interval'].tolist()
    goal_xmin_list = df[df['layer'] == goal_layer]['xmin'].tolist()
    goal_xmax_list = df[df['layer'] == goal_layer]['xmax'].tolist()
    
    overlap_info = []
    i = 0
    #print (goal_layer_number)
    while i < goal_layer_number:
        #print (i)
        x2_min = goal_xmin_list[i]
        x2_max = goal_xmax_list[i]
        if overlap_judge(x1_min, x1_max, x2_min, x2_max)[0] == 1:
            overlap_info.append([goal_interval_list[i], overlap_judge(x1_min, x1_max, x2_min, x2_max)])
        i = i + 1
    return overlap_info

def get_max_overlap_percent(overlap_list):
    if overlap_list == []:
        return 0
    else:
        #print ([x[1][2] for x in overlap_list])
        max_overlap_percent = np.max([x[1][2] for x in overlap_list])
        
        return max_overlap_percent
    
def generate_textgrid_output(df_sub_keep, file):
    # generate textgrif from the datafrom

    xmax_all = np.max(df_sub_keep['xmax'])

    tiers = ['text', 'text']
    tiers_name = ['INT01', 'DAM01'] # rename layer
    tiers_sub = [1,2]


    lines = []
    lines_head = ['File type = "ooTextFile"',
    'Object class = "TextGrid"', '']
    xmin_all = 'xmin = ' + str(0)
    xmax_all = 'xmax = ' + str(xmax_all) # change xmax



    tier_info_general = ['tiers? <exists>', 
    'size = 2', 'item []:'] # change tier number

    sec_all = []
    for i in range(2): # change tier number
        df_curr = df_sub_keep[df_sub_keep['layer'] == tiers_sub[i]] # keep layer 1 and 2
        text_curr = df_curr[tiers[i]].tolist()
    
        xmin_list = df_curr['xmin'].tolist()
        xmax_list = df_curr['xmax'].tolist()

    
        #print (tiers[i])
        tier_info = [ 
        '    item [' + str(i + 1) +']:',
        '        class = "IntervalTier"', 
        '        name = "'+ tiers_name[i] +'"'             
        ]
        interval = 'intervals: size = ' + str(len(text_curr))
        sec_all = sec_all + tier_info + [xmin_all,xmax_all] + [interval]
        for j in range(len(text_curr)):
            interval_curr = 'intervals [' + str(j + 1) + ']:'
            xmin = 'xmin = ' + str(xmin_list[j])
            xmax = 'xmax = ' + str(xmax_list[j])
            text = 'text = "' + str(text_curr[j]) + '"'
            sec_all = sec_all + [interval_curr, xmin, xmax, text]

    lines = lines_head + [xmin_all,xmax_all] + tier_info_general + sec_all
    with open(output_dir + file.split('/')[-1].split('.')[0] + '_overlap_removed_15.Textgrid', 'w') as f: # 15 here indicates the overlap percentage, can change accordingly to remind the threshold choosen
        for line in lines:
            f.write(f"{line}\n")
            
def get_processed_result(input_dir, output_dir):
    # get all textgrid files
    
    files = glob.glob(input_dir + "*.TextGrid")
    for file in files:
        print (file) # print file name
        # change threshold as needed
        df_sub_keep = get_df_from_textgrid(str(file), threshold = 0.15)
        generate_textgrid_output(df_sub_keep, file)

# %%
file = '/Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm001-2022-01-16-Trviž_02.TextGrid'
with open(file, 'r', encoding='utf-8') as file:
    lines = [line.rstrip() for line in file]
lines
# Out:
# ['File type = "ooTextFile"',
#  'Object class = "TextGrid"',
#  '',
#  'xmin = 0',
#  'xmax = 337.482875',
#  'tiers? <exists>',
#  'size = 4',
#  'item []:',
#  '    item [1]:',
#  '        class = "IntervalTier"',
#  '        name = "TEXT@INT01"',
#  '        xmin = 0',
#  '        xmax = 337.482875',
#  '        intervals: size = 32',
#  '        intervals [1]:',
#  '            xmin = 0',
#  '            xmax = 1.9827386500133033',
#  '            text = "Dobro. Ča se domišjaš od djetinjstva, da?"',
#  '        intervals [2]:',
#  '            xmin = 1.9827386500133033',
#  '            xmax = 2.6743558054163663',
#  '            text = ""',
#  '        intervals [3]:',
#  '            xmin = 2.6743558054163663',
#  '            xmax = 7.306489540514602',
#  '            text = "Dobro, od fameje rekla si da vas- @ da si bila (.) z nonići u hiže."',
#  '        intervals [4]:',
#  '            xmin = 7.306489540514602',
#  '            xmax = 7.86632775927532',
#  '            text = "((breath))"',
#  '        intervals [5]:',
#  '            xmin = 7.86632775927532',
#  '            xmax = 9.407325287840374',
#  '            text = "@, kak- @"',
#  '        intervals [6]:',
#  '            xmin = 9.407325287840374',
#  '            xmax = 11.782112184037539',
#  '            text = "Kako- kako je bilo u fameje odrastat z nonići?"',
#  '        intervals [7]:',
#  '            xmin = 11.782112184037539',
#  '            xmax = 17.369999999999997',
#  '            text = "Danas je (.) to retka- (.) retka pojava da se- (.) da je već generacijah skupa."',
#  '        intervals [8]:',
#  '            xmin = 17.369999999999997',
#  '            xmax = 50.21493516237009',
#  '            text = ""',
#  '        intervals [9]:',
#  '            xmin = 50.21493516237009',
#  '            xmax = 50.71234537831936',
#  '            text = "Mhm"',
#  '        intervals [10]:',
#  '            xmin = 50.71234537831936',
#  '            xmax = 52.78106043893212',
#  '            text = ""',
#  '        intervals [11]:',
#  '            xmin = 52.78106043893212',
#  '            xmax = 53.328974128388204',
#  '            text = "Dobro."',
#  '        intervals [12]:',
#  '            xmin = 53.328974128388204',
#  '            xmax = 53.564481093165455',
#  '            text = ""',
#  '        intervals [13]:',
#  '            xmin = 53.564481093165455',
#  '            xmax = 56.399604741765394',
#  '            text = "Kako ste @ u hiže govorili?"',
#  '        intervals [14]:',
#  '            xmin = 56.399604741765394',
#  '            xmax = 56.52635186413033',
#  '            text = ""',
#  '        intervals [15]:',
#  '            xmin = 56.52635186413033',
#  '            xmax = 57.11581193931365',
#  '            text = "Ste govorili do-"',
#  '        intervals [16]:',
#  '            xmin = 57.11581193931365',
#  '            xmax = 61.795051006388654',
#  '            text = ""',
#  '        intervals [17]:',
#  '            xmin = 61.795051006388654',
#  '            xmax = 62.10719102044589',
#  '            text = "Mhm."',
#  '        intervals [18]:',
#  '            xmin = 62.10719102044589',
#  '            xmax = 73.48684545624334',
#  '            text = ""',
#  '        intervals [19]:',
#  '            xmin = 73.48684545624334',
#  '            xmax = 73.80584277561391',
#  '            text = "Mhm."',
#  '        intervals [20]:',
#  '            xmin = 73.80584277561391',
#  '            xmax = 77.03',
#  '            text = ""',
#  '        intervals [21]:',
#  '            xmin = 77.03',
#  '            xmax = 77.19',
#  '            text = "Mhm."',
#  '        intervals [22]:',
#  '            xmin = 77.19',
#  '            xmax = 79.54495193425218',
#  '            text = ""',
#  '        intervals [23]:',
#  '            xmin = 79.54495193425218',
#  '            xmax = 80.00677183472592',
#  '            text = "Dobro."',
#  '        intervals [24]:',
#  '            xmin = 80.00677183472592',
#  '            xmax = 80.69692955713774',
#  '            text = "Ste imali/"',
#  '        intervals [25]:',
#  '            xmin = 80.69692955713774',
#  '            xmax = 81.06407741528123',
#  '            text = "((breath, smack))"',
#  '        intervals [26]:',
#  '            xmin = 81.06407741528123',
#  '            xmax = 88.7662203183768',
#  '            text = "@ obično svi Trvižani se rado domisliju kako su ((breath)) slavili blagdane ili poje- pojedine fešte, recimo za Božić."',
#  '        intervals [27]:',
#  '            xmin = 88.7662203183768',
#  '            xmax = 92.66001062626194',
#  '            text = "Kako ste imali običaj za  Božić, kako ste se doma prontevali za Božić, za Vozan?"',
#  '        intervals [28]:',
#  '            xmin = 92.66001062626194',
#  '            xmax = 93.16',
#  '            text = "Za Telovo, za Rožarovo i tako?"',
#  '        intervals [29]:',
#  '            xmin = 93.16',
#  '            xmax = 95.03081939441066',
#  '            text = "Za Telovo, za Rožarovo, i tako."',
#  '        intervals [30]:',
#  '            xmin = 95.03081939441066',
#  '            xmax = 306.964692486174',
#  '            text = ""',
#  '        intervals [31]:',
#  '            xmin = 306.964692486174',
#  '            xmax = 307.45422296369867',
#  '            text = "Mhm."',
#  '        intervals [32]:',
#  '            xmin = 307.45422296369867',
#  '            xmax = 337.482875',
#  '            text = ""',
#  '    item [2]:',
#  '        class = "IntervalTier"',
#  '        name = "Words@INT01"',
#  '        xmin = 0',
#  '        xmax = 337.482875',
#  '        intervals: size = 116',
#  '        intervals [1]:',
#  '            xmin = 0',
#  '            xmax = 0.23806262717969406',
#  '            text = "Dobro. "',
#  '        intervals [2]:',
#  '            xmin = 0.23806262717969406',
#  '            xmax = 0.3850518271348469',
#  '            text = "Ča"',
#  '        intervals [3]:',
#  '            xmin = 0.3850518271348469',
#  '            xmax = 0.4494628248680038',
#  '            text = "se"',
#  '        intervals [4]:',
#  '            xmin = 0.4494628248680038',
#  '            xmax = 0.9019913730445418',
#  '            text = "domišjaš"',
#  '        intervals [5]:',
#  '            xmin = 0.9019913730445418',
#  '            xmax = 1.0324649325552955',
#  '            text = "od"',
#  '        intervals [6]:',
#  '            xmin = 1.0324649325552955',
#  '            xmax = 1.6914389862868235',
#  '            text = "djetinjstva"',
#  '        intervals [7]:',
#  '            xmin = 1.6914389862868235',
#  '            xmax = 1.9827386500133033',
#  '            text = "da"',
#  '        intervals [8]:',
#  '            xmin = 1.9827386500133033',
#  '            xmax = 2.6743558054163663',
#  '            text = ""',
#  '        intervals [9]:',
#  '            xmin = 2.6743558054163663',
#  '            xmax = 3.243532845510337',
#  '            text = "dobro"',
#  '            xmin = 94.00883319823029',
#  '            xmax = 94.71602055047829',
#  '            text = "Rožarovo"',
#  '        intervals [114]:',
#  '            xmin = 94.71602055047829',
#  '            xmax = 94.82425940917969',
#  '            text = "i"',
#  '        intervals [115]:',
#  '            xmin = 94.82425940917969',
#  '            xmax = 95.03081939441066',
#  '            text = "tako"',
#  '        intervals [116]:',
#  '            xmin = 95.03081939441066',
#  '            xmax = 337.482875',
#  '            text = ""',
#  '    item [3]:',
#  '        class = "IntervalTier"',
#  '        name = "TEXT@TRV01"',
#  '        xmin = 0',
#  '        xmax = 337.482875',
#  '        intervals: size = 86',
#  '        intervals [1]:',
#  '            xmin = 0',
#  '            xmax = 1.7169161864290776',
#  '            text = "Ča se tiče- da, (.) da"',
#  '        intervals [2]:',
#  '            xmin = 1.7169161864290776',
#  '            xmax = 1.9827386500133033',
#  '            text = ""',
#  '        intervals [3]:',
#  '            xmin = 1.9827386500133033',
#  '            xmax = 2.638107287654881',
#  '            text = "nešto"',
#  '        intervals [4]:',
#  '            xmin = 2.638107287654881',
#  '            xmax = 17.369999999999997',
#  '            text = ""',
#  '        intervals [5]:',
#  '            xmin = 17.369999999999997',
#  '            xmax = 18.021675474613286',
#  '            text = "((smack))"',
#  '        intervals [6]:',
#  '            xmin = 18.021675474613286',
#  '            xmax = 20.367020446627514',
#  '            text = "Hm, vjerovatno, ča ja znan."',
#  '        intervals [7]:',
#  '            xmin = 20.367020446627514',
#  '            xmax = 23.53025863552194',
#  '            text = "Nisi zna za drugo pa ti je normalno bilo (.) da si z nonići."',
#  '        intervals [8]:',
#  '            xmin = 23.53025863552194',
#  '            xmax = 26.37554658990031',
#  '            text = "Skoro svi smo bili z nonići, ja ne znan, (.) u biti."',
#  '        intervals [9]:',
#  '            xmin = 26.37554658990031',
#  '            xmax = 26.779500517867923',
#  '            text = "((breath))"',
#  '        intervals [10]:',
#  '            xmin = 26.779500517867923',
#  '            xmax = 33.95243414958444',
#  '            text = "Forši te mlaje generacije, one su @ šli sami, ali mi, moja generacija, svi stareji smo stavali z nonići."',
#  '        intervals [11]:',
#  '            xmin = 33.95243414958444',
#  '            xmax = 34.447830558991406',
#  '            text = "((breath))"',
#  '        intervals [12]:',
#  '            xmin = 34.447830558991406',
#  '            xmax = 42.04042961394876',
#  '            text = "Hm bilo nan je to potpuno normalno, ni- ča ja znan, forši- forši čak i još boje jer se niki ni sme karat pred niken."',
#  '        intervals [13]:',
#  '            xmin = 42.04042961394876',
#  '            xmax = 42.70978977477574',
#  '            text = "((breath))"',
#  '        intervals [14]:',
#  '            xmin = 42.70978977477574',
#  '            xmax = 44.25692894093158',
#  '            text = "Baren (.) ne preveć"',
#  '        intervals [15]:',
#  '            xmin = 44.25692894093158',
#  '            xmax = 44.7116126303435',
#  '            text = ""',
#  '        intervals [16]:',
#  '            xmin = 44.7116126303435',
#  '            xmax = 45.69307746454647',
#  '            text = "Ni se znalo."',
#  '        intervals [17]:',
#  '            xmin = 45.69307746454647',
#  '            xmax = 46.41043731557425',
#  '            text = ""',
#  '        intervals [18]:',
#  '            xmin = 46.41043731557425',
#  '            xmax = 47.88007313844713',
#  '            text = "@, ne znan, ne znan."',
#  '        intervals [19]:',
#  '            xmin = 47.88007313844713',
#  '            xmax = 52.31807404336784',
#  '            text = " Meni- ja nisan znala za drugo pa meni je bilo u redu, a- (.) ča ja znan. "',
#  '        intervals [20]:',
#  '            xmin = 52.31807404336784',
#  '            xmax = 56.774346338514384',
#  '            text = ""',
#  '        intervals [21]:',
#  '            xmin = 56.774346338514384',
#  '            xmax = 62.33877877281094',
#  '            text = "Doma smo govorili trviški @ jer su nono i nona od ćaća Trvižani, kako i ćaća."',
#  '        intervals [22]:',
#  '            xmin = 62.33877877281094',
#  '            xmax = 62.77930970879564',
#  '            text = "((breath))"',
#  '        intervals [23]:',
#  '            xmin = 62.77930970879564',
#  '            xmax = 71.97827664950124',
#  '            text = "Mama mi je @ blizu- blizu isto tako jene- iz Ježenja, bliz- mesto blizu Pazina, ali uni govoriju već ikavicu ((breath)) i drugajče."',
#  '        intervals [24]:',
#  '            xmin = 71.97827664950124',
#  '            xmax = 76.5007271349322',
#  '            text = "@ nisan nikat @ nanke jenu besedu, ja mislin, rekla njenu."',
#  '        intervals [25]:',
#  '            xmin = 76.5007271349322',
#  '            xmax = 77.1901737206209',
#  '            text = ""',
#  '        intervals [26]:',
#  '            xmin = 77.1901737206209',
#  '            xmax = 79.20022864140783',
#  '            text = " A Trviški hm i to je to. "',
#  '        intervals [27]:',
#  '            xmin = 79.20022864140783',
#  '            xmax = 92.66001062626194',
#  '            text = ""',
#  '        intervals [28]:',
#  '            xmin = 92.66001062626194',
#  '            xmax = 93.29940627103451',
#  '            text = "((breath, smack))"',
#  '        intervals [29]:',
#  '            xmin = 93.29940627103451',
#  '            xmax = 95.64491538857351',
#  '            text = "@ da, @ forši da."',
#  '        intervals [30]:',
#  '            xmin = 95.64491538857351',
#  '            xmax = 104.301588935346',
#  '            text = "Najveće te fešte z-, mislin najveće, meni kao utroku, (.) vjerojatno san hi tako gledala ((breath)) je bi Božić i Vazan, @ Vazan već."',
#  '        intervals [31]:',
#  '            xmin = 104.301588935346',
#  '            xmax = 104.5997279994276',
#  '            text = ""',
#  '        intervals [32]:',
#  '            xmin = 104.5997279994276',
#  '            xmax = 117.84966517160035',
#  '            text = "@ za Božić ((breath)), a niš, vajk se je šlo, obavezno, ne znan,  spovedi ((breath)) i @ na polnoćku (.) i drugi dan se je šlo h maše, u jedanajs ur, i pole je bila užina,"',
#  '        intervals [33]:',
#  '            xmin = 117.84966517160035',
#  '            xmax = 118.27713306570902',
#  '            text = "((breath))"',
#  '        intervals [34]:',
#  '            xmin = 118.27713306570902',
#  '            xmax = 119.77892898722685',
#  '            text = "@ samo mi ča smo bili doma"',
#  '        intervals [35]:',
#  '            xmin = 119.77892898722685',
#  '            xmax = 123.09625941121091',
#  '            text = "znači, nono i nona, mama i ćaća, i brat i sest- sestra"',
#  '        intervals [36]:',
#  '            xmin = 123.09625941121091',
#  '            xmax = 134.99875298232863',
#  '            text = "A navečer ((breath)) su došle- su došli @ sve sestre od ćaća i njihovja- (.) njihova dica pa smo se družili, ((breath)) vajk se je nešto speklo ili narezalo, ne znan, pršut ili tako ča."',
#  '        intervals [37]:',
#  '            xmin = 134.99875298232863',
#  '            xmax = 135.28847502990664',
#  '            text = "((breath))"',
#  '        intervals [38]:',
#  '            xmin = 135.28847502990664',
#  '            xmax = 145.9957308589767',
#  '            text = "Za Vazan isto tako, @ hm forši se je već časti, ne forši nego je vajk, (.) uglavnon za sve te veće fešte smo morali sve ufregat i učistit ((breath)) koltrine, laštre, ne znan,"',
#  '        intervals [39]:',
#  '            xmin = 145.9957308589767',
#  '            xmax = 157.32992923038861',
#  '            text = "Sve zvadit van iz @ ((breath)) armarići tamo kade je bila una posuda koja se je ((click)) čuvala, ča je dobila mama i ćaća za- za svate ili tako nešto, i s- hm vajk je tamo samo stalo u vetrini."',
#  '        intervals [40]:',
#  '            xmin = 157.32992923038861',
#  '            xmax = 158.24135195617245',
#  '            text = "((breath))"',
#  '        intervals [41]:',
#  '            xmin = 158.24135195617245',
#  '            xmax = 166.93589946531648',
#  '            text = "Onda, se je- hm sve se malo boje ufregalo dole pred vrati, konobu i ča ja znan ča, za ob- za sve te fešte, dva tri put na leto se je to delalo"',
#  '        intervals [42]:',
#  '            xmin = 166.93589946531648',
#  '            xmax = 167.70430181323428',
#  '            text = "((breath, click))"',
#  '        intervals [43]:',
#  '            xmin = 167.70430181323428',
#  '            xmax = 170.62683550482265',
#  '            text = "@ to je bi naravno povot, te veće fešte."',
#  '        intervals [44]:',
#  '            xmin = 170.62683550482265',
#  '            xmax = 183.90084991021598',
#  '            text = "A za Vazan obavezno smo šli svi, i za Božić naravno nan ((breath)) je doša plovan blagoslovit, ali (.) živimo u mestu kade su to svi d- delali, tako da, ča ja znan, da li je to potrebno nanke istaknat, ali dobro, forši je. "',
#  '        intervals [45]:',
#  '            xmin = 183.90084991021598',
#  '            xmax = 184.55364254376536',
#  '            text = "((breath))"',
#  '        intervals [46]:',
#  '            xmin = 184.55364254376536',
#  '            xmax = 193.3109883677964',
#  '            text = "@ znači Vazan, e @ za Veliku sredu je velika, odnosno ot kat ja znan za se, vajk bila spovet, (.) ((breath, click)) @ župna. "',
#  '        intervals [47]:',
#  '            xmin = 193.3109883677964',
#  '            xmax = 193.51271464212303',
#  '            text = ""',
#  '        intervals [48]:',
#  '            xmin = 193.51271464212303',
#  '            xmax = 203.72968204817897',
#  '            text = "Onda u četrtak, na Veliki četrtak se je obavezno  šlo h maše ((breath)) @ kade se je naravno častila ta, ((hh)) @ odnosno slavila posljednja večera. "',
#  '        intervals [49]:',
#  '            xmin = 203.72968204817897',
#  '            xmax = 204.18352030576244',
#  '            text = "((breath))"',
#  '        intervals [50]:',
#  '            xmin = 204.18352030576244',
#  '            xmax = 219.313735415599',
#  '            text = "A u petak @ se je šlo, na Veliki petak na obrede (.) i opet ((breath)) se je šlo u subotu, (.) u jedanajs ur je bila, (.) mislin prvo su bili obredi pa pole ((breath)) maša, i u nedeju, obavezno, na Vazan se je šlo h maše."',
#  '        intervals [51]:',
#  '            xmin = 219.313735415599',
#  '            xmax = 219.76095843531752',
#  '            text = "((breath))"',
#  '        intervals [52]:',
#  '            xmin = 219.76095843531752',
#  '            xmax = 224.62514821135855',
#  '            text = "A prontevali smo ((hh)) @ u subotu ((breath)) jaja se je korolevalo. "',
#  '        intervals [53]:',
#  '            xmin = 224.62514821135855',
#  '            xmax = 224.7928471531915',
#  '            text = ""',
#  '        intervals [54]:',
#  '            xmin = 224.7928471531915',
#  '            xmax = 236.88985359027342',
#  '            text = "@ jaja smo korolevali tako da se je, mislin to se dela i dan danas tako, ((breath)) @ tako da smo vrgli @ jaja kuhat u ((click)) @ lup od @ žbule."',
#  '        intervals [55]:',
#  '            xmin = 236.88985359027342',
#  '            xmax = 237.28068942104542',
#  '            text = "((breath))"',
#  '        intervals [56]:',
#  '            xmin = 237.28068942104542',
#  '            xmax = 240.38',
#  '            text = "A hm @ hm, ((breath)) ča ja znan."',
#  '        intervals [57]:',
#  '            xmin = 240.38',
#  '            xmax = 240.83408321890136',
#  '            text = "Hm."',
#  '        intervals [58]:',
#  '            xmin = 240.83408321890136',
#  '            xmax = 251.09238637512598',
#  '            text = "Uregulalo se hi je tako da se je vrglo neki listi i to se je ćepalo z ((breath)) žabicon, nekon prekinjenon od none ili mame pa se je to vrglo tako kuhat, onda se je vrgla plećka kuhat."',
#  '        intervals [59]:',
#  '            xmin = 251.09238637512598',
#  '            xmax = 251.7994133627091',
#  '            text = "((breath))"',
#  '        intervals [60]:',
#  '            xmin = 251.7994133627091',
#  '            xmax = 257.301419989409',
#  '            text = "A drugi dan za @ za- nu, se je jelo to, ali s- to je bilo za, u stvari"',
#  '        intervals [61]:',
#  '            xmin = 257.301419989409',
#  '            xmax = 257.60267495436113',
#  '            text = "((click))"',
#  '        intervals [62]:',
#  '            xmin = 257.60267495436113',
#  '            xmax = 260.189847671218',
#  '            text = "U biti, ((breath)) kad smo došli iz @-"',
#  '        intervals [63]:',
#  '            xmin = 260.189847671218',
#  '            xmax = 261.0032134698801',
#  '            text = ""',
#  '        intervals [64]:',
#  '            xmin = 261.0032134698801',
#  '            xmax = 269.9449970878466',
#  '            text = "hm @ u su- u subotu navečer u jenu uru za polnoći doma iz maše, ((breath)) onda @ se je jelo blagoslovno sve, tako je bi običaj."',
#  '        intervals [65]:',
#  '            xmin = 269.9449970878466',
#  '            xmax = 274.75821708362434',
#  '            text = "Znači se je poje luk blagoslovni, ((breath)) jaje, sol i kruh."',
#  '        intervals [66]:',
#  '            xmin = 274.75821708362434',
#  '            xmax = 274.84',
#  '            text = ""',
#  '        intervals [67]:',
#  '            xmin = 274.84',
#  '            xmax = 278.96887300622797',
#  '            text = "@ mi nismo nikat blagoslovili plećku, forši neki su, mi nismo. "',
#  '        intervals [68]:',
#  '            xmin = 278.96887300622797',
#  '            xmax = 279.26886149603104',
#  '            text = "((breath))"',
#  '        intervals [69]:',
#  '            xmin = 279.26886149603104',
#  '            xmax = 280.3682987980127',
#  '            text = "To se pojelo zajno."',
#  '        intervals [70]:',
#  '            xmin = 280.3682987980127',
#  '            xmax = 288.66783312577326',
#  '            text = "Mi nismo- mi nikat nismo imali običaj  da je bi neki, ((breath)) hm ne znan, kako ča reču doručak, mi to nismo imali nikat, znači mi smo sve pojeli zajno pole maše."',
#  '        intervals [71]:',
#  '            xmin = 288.66783312577326',
#  '            xmax = 289.0350554034397',
#  '            text = "((breath))"',
#  '        intervals [72]:',
#  '            xmin = 289.0350554034397',
#  '            xmax = 291.9330623622857',
#  '            text = " Drugi d- i- i onda plećka se je načela i se je jela, "',
#  '        intervals [73]:',
#  '            xmin = 291.9330623622857',
#  '            xmax = 292.5951322704133',
#  '            text = ""',
#  '        intervals [74]:',
#  '            xmin = 292.5951322704133',
#  '            xmax = 294.26019351925504',
#  '            text = "je bila dobra unako još tepla."',
#  '        intervals [75]:',
#  '            xmin = 294.26019351925504',
#  '            xmax = 294.7407265431893',
#  '            text = "((breath))"',
#  '        intervals [76]:',
#  '            xmin = 294.7407265431893',
#  '            xmax = 304.9336710006644',
#  '            text = "I drugi dan, normalno, ča ja znan, šugo, ((breath)) testo, juha, č- ovisi kako ča, ča ja znan, neke pute sarme, sat više ne znan, kako se dogovori."',
#  '        intervals [77]:',
#  '            xmin = 304.9336710006644',
#  '            xmax = 305.1918878450551',
#  '            text = "((breath))"',
#  '        intervals [78]:',
#  '            xmin = 305.1918878450551',
#  '            xmax = 307.5',
#  '            text = "Ne u- u stvari jančić anke je uža bit,"',
#  '        intervals [79]:',
#  '            xmin = 307.5',
#  '            xmax = 307.96251101949395',
#  '            text = "((breath))"',
#  '        intervals [80]:',
#  '            xmin = 307.96251101949395',
#  '            xmax = 310.7739986001635',
#  '            text = "@ se je speka jančić za- za- za Vazan."',
#  '        intervals [81]:',
#  '            xmin = 310.7739986001635',
#  '            xmax = 314.15836588280814',
#  '            text = "I navečer su steši jopet došli svi i onda se je jela ta plećka. "',
#  '        intervals [82]:',
#  '            xmin = 314.15836588280814',
#  '            xmax = 318.969825910983',
#  '            text = "Znači sve te ses- sestre od ćaća ((breath))  i njihove fameje, se je jela plećka, to je to. "',
#  '        intervals [83]:',
#  '            xmin = 318.969825910983',
#  '            xmax = 332.12',
#  '            text = "A na vazmeni ponedejak smo šli poli ((breath)) @ nonića i none od mame i tamo smo šli na užinu i su došli od mame ((breath)) brati i sestra, tamo je bilo drugajče, se je šlo na vazmeni ponedejak poli nas. "',
#  '        intervals [84]:',
#  '            xmin = 332.12',
#  '            xmax = 334.71493493900346',
#  '            text = "Za Vazan smo bili doma, ali su drugi došli poli nas."',
#  '        intervals [85]:',
#  '            xmin = 334.71493493900346',
#  '            xmax = 335.3858053492259',
#  '            text = "((breath))"',
#  '        intervals [86]:',
#  '            xmin = 335.3858053492259',
#  '            xmax = 337.482875',
#  '            text = "I ča ja znan još ča tako ot tega."',
#  '    item [4]:',
#  '        class = "IntervalTier"',
#  '        name = "WORDS@TRV01"',
#  '        xmin = 0',
#  '        xmax = 337.482875',
#  '        intervals: size = 968',
#  '        intervals [1]:',
#  '            xmin = 0',
#  '            xmax = 0.15642890937009077',
#  '            text = "ča"',
#  '        intervals [2]:',
#  '            xmin = 0.15642890937009077',
#  '            xmax = 0.26295479023646556',
#  '            text = "se"',
#  '        intervals [3]:',
#  '            xmin = 0.26295479023646556',
#  '            xmax = 0.765856041768421',
#  '            text = "tiče"',
#  '        intervals [4]:',
#  '            xmin = 0.765856041768421',
#  '            xmax = 1.0061586102344293',
#  '            text = "da"',
#  '        intervals [5]:',
#  '            xmin = 1.0061586102344293',
#  '            xmax = 1.4173980572999694',
#  '            text = ""',
#  '        intervals [6]:',
#  '            xmin = 1.4173980572999694',
#  '            xmax = 1.7146795852991548',
#  '            text = "da"',
#  '        intervals [7]:',
#  '            xmin = 1.7146795852991548',
#  '            xmax = 1.9827386500133033',
#  '            text = ""',
#  '        intervals [8]:',
#  '            xmin = 1.9827386500133033',
#  '            xmax = 2.6387296681632897',
#  '            text = "nešto"',
#  ...]

# %%
input_dir = "/Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/" # folder name that contains all the textgrid files
output_dir = "/Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008_overlap_removed/" # output dir that stores all the new textgrid files

if not os.path.exists(output_dir):
    os.makedirs(output_dir) # make output dir if not exist
threshold = 0.15        
get_processed_result(input_dir, output_dir)    # will print out the files that have been processed
# Out:
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm006-2023-05-28-Kostrena_07.TextGrid
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm006-2023-05-28-Kostrena_06.TextGrid
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm001-2022-01-16-Trviž_02.TextGrid
# <ipython-input-108-d83b54638f53>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['overlap'] = df_sub.apply(lambda x: overlap_record(df_sub, x.layer, x.interval), axis = 1)
# <ipython-input-108-d83b54638f53>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['overlap_max'] = df_sub['overlap'].apply(lambda x: get_max_overlap_percent(x))
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm001-2022-01-16-Trviž_03.TextGrid
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm005-2022-11-26-Vrbnik_06.TextGrid
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm002-2022-01-04-Crikvenica_01.TextGrid
# /Users/irisz/downloads/2023_ELIC/croatian/croatian_manual_annotated_1008/ckm005-2022-11-26-Vrbnik_01.TextGrid
