# %%
# load transcription from all whisper fine-tuned models
# get list 

import glob
dir_list = glob.glob("/home/sz38235/workDir/elic/whisper_test/*.csv")
dir_list
# Out:
# ['/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_09_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_05_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_07_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_08_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_04_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_06_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_05_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm009-2023-05-26-Žminj_02_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_04_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_06_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm009-2023-05-26-Žminj_03_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_12_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_03_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_01_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm009-2023-05-26-Žminj_04_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_10_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_03_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_11_whisper_all.csv',
#  '/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_01_whisper_all.csv']

# %%
dir_list_2 = ['/home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_02_whisper_all.csv',
'/home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_02_whisper_all.csv',
'/home/sz38235/workDir/elic/whisper_test/ckm009-2023-05-26-Žminj_01_whisper_all.csv']

# %%
len(dir_list)
# Out:
# 19

# %%
import re
import pandas as pd
from Bio import pairwise2
from thefuzz import fuzz
import numpy as np

def clean_text(text):
    if text == 'x':
        return ''
    # remove () pattern, will leave a ) to be removed
    text = re.sub(r'\(([^)]+)\)', '', text)
    special_char_list = [',', '.', '?', '#', '@', '-', ')', ':']
    for char in special_char_list:
        text = text.replace(char, '')
    # change all text to lower cases
    text = text.lower()
    return text

def get_clean_word_list(text):
    new_text = clean_text(text)
    word_list = new_text.split(' ')
    word_list_clean = list(filter(None, word_list))
    return word_list_clean

def get_aligned_list(l1, l2):
    # get aligned list, along with wer type and fuzz match score
    alignments = pairwise2.align.globalxx(l1, 
                                      l2,
                                      gap_char=['-']
                                     )
    l1_align = alignments[0].seqA
    l2_align = alignments[0].seqB
    score = []
    for i in range(len(l1_align)):
        score.append(word_match_score(l1_align[i], l2_align[i]))
    return l1_align, l2_align, score


def word_match_score(t1, t2):
    if t1 == '-' or t2 == '-':
        return 0
    else:
        score = fuzz.ratio(t1, t2)
        return score

def get_matched(t1, t2):
    #print (t1, t2)
    if t1 == t2:
            return 1
    else:
        return 0
    
def get_unmatched_cand(match_list, idx):
    cand = []
    idx_org = idx
    if match_list[idx] == 1:
        return [idx]
    else:
        while match_list[idx] != 1 and idx > 0:
            cand.append(idx)
            idx = idx - 1 # before
        idx = idx_org
        while match_list[idx] != 1 and idx < len(match_list) -1:
            cand.append(idx)
            idx = idx + 1 # after
        return list(set(cand))
    
def get_can_score(idx,match_cand, df_align):
    if len(match_cand) == 1:
        return [100]
    score_all = []
    for cand in match_cand:
        t1 = df_align['manual'][idx]
        t2 = df_align['model'][cand]
        score = word_match_score(t1, t2)
        score_all.append(score)
    return score_all

def get_fuzzy_cand(match_cand, match_cand_score, df_align):
    max_cand = np.max(match_cand_score)
    if max_cand > 60:
        # fuzzy matched
        max_cand_id = match_cand[match_cand_score.index(max_cand)]
        #print (max_cand_id)
        word = df_align['model'][max_cand_id]
        return word, max_cand, max_cand_id
    else:
        return '-', 0, '-'
    
def get_error_type(t1, t2):
    if (t1 != '-') and (t2 != '-') and (t1 != t2):
        return 's'
    if (t1 != '-') and (t2 == '-'):
        return 'd'
    if (t1 == '-') and (t2 != '-'):
        return 'i'
    if (t1 != '-') and (t2 != '-') and (t1 == t2):
        return 'c'
    if t1 == '':
        return ""
    
def get_wer_from_df(df):
    s = len(df[df['error_type_correct'] == 's'])
    d = len(df[df['error_type_correct'] == 'd'])
    i = len(df[df['error_type_correct'] == 'i'])
    c = len(df[df['error_type_correct'] == 'c'])
    n = s + d + c
    if n == 0:
        return "inf"
    wer = (s + d + i)/n * 100
    return wer,s,d,i,c,n

def get_df_align_and_wer_info(df, model_name, file_name):
    save_dir = '/home/sz38235/workDir/elic/whisper_wer/' + file_name.split('/')[-1].split('whisper')[0] + model_name + '.csv'
    manual_all = []
    model_all = []
    model_fuzzy_all = []
    error_type_all = []
    wer_all = []
    for id in range(len(df)):
        text1 = df['text'][id]
        text2 = df[model_name][id]
        l1 = get_clean_word_list(text1)
        l2 = get_clean_word_list(text2)
        if l1 == []:
            l1 = [""]
        if l2 == []:
            l2 = [""]
        #print (l1, l2)
        df_align = pd.DataFrame(columns = ['manual', 'model'])
        df_align['manual'] = get_aligned_list(l1, l2)[0]
        df_align['model'] = get_aligned_list(l1, l2)[1]
        df_align['score'] = get_aligned_list(l1, l2)[2]
        df_align['match'] = df_align.apply(lambda x:get_matched(x.manual, x.model), axis = 1)
        df_align['idx'] = df_align.index
        df_align['match_cand'] = df_align.apply(lambda x: get_unmatched_cand(df_align['match'].tolist(), x.idx), axis = 1)
        df_align['match_cand_score'] = df_align.apply(lambda x: get_can_score(x.idx, x.match_cand, df_align), axis = 1)
        df_align['model_fuzzy'] = df_align.apply(lambda x: get_fuzzy_cand(x.match_cand, x.match_cand_score, df_align)[0], axis = 1)
        df_align['model_fuzzy_id'] = df_align.apply(lambda x: get_fuzzy_cand(x.match_cand, x.match_cand_score, df_align)[2], axis = 1)
        df_align['model_fuzzy_score'] = df_align.apply(lambda x: get_fuzzy_cand(x.match_cand, x.match_cand_score, df_align)[1], axis = 1)
        df_align['error_type'] = df_align.apply(lambda x: get_error_type(x.manual, x.model), axis = 1)
        sub_id = df_align[(df_align['error_type']=='d') & (df_align['model_fuzzy_id'] != '-')]['model_fuzzy_id'].tolist()
        del_sub_id = df_align[(df_align['error_type']=='d') & (df_align['model_fuzzy_id'] != '-')].index.tolist()
        error_type = df_align['error_type'].tolist()
        for id in del_sub_id:
            error_type[id] = 's'
        df_align['error_type_correct'] = error_type
        df_align_clean = df_align[~df_align.index.isin(sub_id)]

        manual_curr = df_align_clean['manual'].tolist()
        model_fuzzy_curr  = df_align_clean['model_fuzzy'].tolist()
        error_type  = df_align_clean['error_type_correct'].tolist()
        model_curr = df_align_clean['model'].tolist()
        wer_curr = get_wer_from_df(df_align_clean)
        
        manual_all = manual_all + manual_curr
        model_fuzzy_all = model_fuzzy_all + model_fuzzy_curr
        error_type_all = error_type_all + error_type
        model_all = model_all + model_curr
        wer_all.append(wer_curr)
    df_all = pd.DataFrame(columns = ['manual', 'model', 'model_fuzzy', 'error_type'])
    df_all['manual'] = manual_all
    df_all['model'] = model_all
    df_all['model_fuzzy'] = model_fuzzy_all
    df_all['error_type'] = error_type_all
    
    df_all.to_csv(save_dir)
    return wer_all
# Out:
# /home/sz38235/.local/lib/python3.11/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
for file_id in range(len(dir_list)):
#for file_id in range(1):
    file_name = dir_list[file_id]
    print (file_name)
    df = pd.read_csv(file_name)
    for model_id in range(1, 11):
        model_name = 'transcription_v' + str(int(model_id))
        print (model_name)
        col = model_name + '_wer'
        df[col] = get_df_align_and_wer_info(df, model_name, file_name)
    df['text_clean']= df['text'].apply(lambda x: clean_text(x))
    df.to_csv('/home/sz38235/workDir/elic/whisper_wer/' + file_name.split('/')[-1].split('whisper')[0]  + 'all_model_wer.csv')
# Out:
# /home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_09_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_05_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm009-2023-05-26-Žminj_04_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_10_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm015-2023-06-08-Klana_03_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_11_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10
# /home/sz38235/workDir/elic/whisper_test/ckm016-2023-06-10-Klana_01_whisper_all.csv
# transcription_v1
# transcription_v2
# transcription_v3
# transcription_v4
# transcription_v5
# transcription_v6
# transcription_v7
# transcription_v8
# transcription_v9
# transcription_v10

# %%
df
# Out:
#     Unnamed: 0                     chunk_name  file_tier       start  \
# 0            0   ckm016-2023-06-10-Klana_01_1          1    0.219319
# 1            1   ckm016-2023-06-10-Klana_01_2          1   85.947592
# 2            2   ckm016-2023-06-10-Klana_01_3          1  216.672562
# 3            3   ckm016-2023-06-10-Klana_01_4          1  394.253003
# 4            4   ckm016-2023-06-10-Klana_01_5          1  482.519859
# 5            5   ckm016-2023-06-10-Klana_01_1          2    7.092442
# 6            6   ckm016-2023-06-10-Klana_01_2          2   20.443752
# 7            7   ckm016-2023-06-10-Klana_01_3          2   32.090036
# 8            8   ckm016-2023-06-10-Klana_01_4          2   46.318426
# 9            9   ckm016-2023-06-10-Klana_01_5          2   56.711196
# 10          10   ckm016-2023-06-10-Klana_01_6          2   68.772819
# 11          11   ckm016-2023-06-10-Klana_01_7          2   83.041179
# 12          12   ckm016-2023-06-10-Klana_01_8          2   94.186788
# 13          13   ckm016-2023-06-10-Klana_01_9          2  111.597698
# 14          14  ckm016-2023-06-10-Klana_01_10          2  124.830378
# 15          15  ckm016-2023-06-10-Klana_01_11          2  135.632098
# 16          16  ckm016-2023-06-10-Klana_01_12          2  151.224245
# 17          17  ckm016-2023-06-10-Klana_01_13          2  162.473692
# 18          18  ckm016-2023-06-10-Klana_01_14          2  175.136980
# 19          19  ckm016-2023-06-10-Klana_01_15          2  188.190630
# 20          20  ckm016-2023-06-10-Klana_01_16          2  200.398134
# 21          21  ckm016-2023-06-10-Klana_01_17          2  213.612485
# 22          22  ckm016-2023-06-10-Klana_01_18          2  225.455021
# 23          23  ckm016-2023-06-10-Klana_01_19          2  238.873293
# 45  522.322895       126     128
# 46  536.151854       128     132
# 47  547.918609       132     136
# 48  561.921870       136     141
# 49  572.910289       141     144
# 50  585.819354       144     148
# 51  596.290551       148     153
#
#                                                  text  \
# 0   Pa- sad moremo po naše, sa se moremo prehitit ...
# 1                                                Mhm.
# 2                                          ((laughs))
# 3                                          ((laughs))
# 4                                                Mhm.
# 5   Rojen san va Klani, sedamnajst dvanajstiga ped...
# 6   @ ((noise)) Nisan puno navadiv (.) tatinih bes...
# 7   Živiv san z mamu,  i živiv san s staru nonu. O...
# 8   si smo govorili va Klani po klanjski. Tako da-...
# 9   Aš je to bila za nas ena- (.) ena čudna stvar,...
# 10  enu stvar iz drugiga razreda ka je za- ka se j...
# 11  prvimu razredu ki je biv prijet va pionire. Mi...
# 12  A glavninu pjesme je recitirav (.) naš najbolj...
# 13  va bile stomanje, stavite črljeni facov i pion...
# 14  hulahopke ženske i kratke brageše do kasno va ...
# 15  Te hulahopke su bile- to je bilo eno brižno vr...
# 16  Ali te hulahopke su se zvale hlače. Va Klani i...
# 17  Učiteljica je rekla- (.) ovo ponavljan još eda...
# 18     on je rekav:  I Mladen je prišav na pozornicu.
# 19  Va kratkih plavih bragešah i va tih pokrpanih ...
# 20  I ona da je- nas je bilo puno va razredu, mord...
# 21  Njemu ni bilo jasno zač on ne smi recitirat. (...
# 22  Evo tako da su dica imela problema s hrvackin,...
# 23  Potle, @- jednostavno, hm kako je vrime pasiva...
# 24  E sada, kako je nas bilo puno, i dan danas su ...
# 25  I kada smo mi teli (.), ja i Tone, storit ovu ...
# 26  sina. I govorin, radi kurioziteta, biš li ti p...
# 27  Aš to je meni- on govori klanjski (.) perfektn...
# 28  @ Kako je nas bila većina, nje smo navadili po...
# 29  E! Navadiv san se puno besid ke se sada ne upo...
# 30  Vežene su za šumu, vežene su za polje, vežene ...
# 31  Volin pisat po klanjski. @ Još man enu- enu sm...
# 32  va glavi, ga ne minjaš. Šav san va vojsku. Va ...
# 33  A va Klani se reče  I ja san rekav: (.)  I si ...
# 34  Aš san rekav ja  Kada smo prišli na glavnu- na...
# 35  ((laughs)) To je- (.) evo, to bilo od mojiga k...
# 36  sada mi se j' dogodilo, pred malo vrimena mi s...
# 37                                           Govorin:
# 38         Na eni priredbi.  ti si mi biv jako čudan.
# 39  ((laughs)) (No) govorin, dobro je. Pa da san j...
# 40  Znan da se je va moj govor pomišalo puno besid...
# 41  ((hhh)) Bez da će, čovik prime i njihov naglas...
# 42  Evo, m- m- m- meni bi rekav Šnajdar da je čut ...
# 43  @ ((hits table)) Ne glumin. Govorin baš onako ...
# 44  puno stvari ke- ke- kih morda ni drugdi. Recim...
# 45  Kada su šli va šumu, (.) su šli va goru, (.) g...
# 46  Kada je loš čovik, je gori. Vavik je gori. Kad...
# 47  Ena besida po čet- ma četiri značenja. Kaj ja ...
# 48  je bilo kada je bilo, je bilo. Tako, ena besid...
# 49  drukčiji je naglasak, ali ista besida je za pa...
# 50  puno- (.) puno- jeziki, ljudi su od sih nič pr...
# 1                                                  A.  ...
# 2   .)laughs). A on je prišal poklalala pok pok po...  ...
# 3   .)laughs). To je, evo, to bi bilo od mojega kl...  ...
# 4                                                Aha.  ...
# 5   Rojen san va Klani 17.12.51. Mama je Klanjica,...  ...
# 6   O- Nisan puno navadiv tatinih besidašnon mladu...  ...
# 7   Živil san z mamu i živil san staru nonu. Od nj...  ...
# 8   Si smo govorili va klani, poklanjski. Tako da,...  ...
# 9   aš je, to bila za nas ena čudna stvar, nepozna...  ...
# 10  enu štvar iz drugiga razreda ka je za- ka se j...  ...
# 11  prvim u razredu, ki je bil prijet va pionire. ...  ...
# 12  A glavninu pjesme je recitiral naš najbolji uč...  ...
# 13  Va bile stomanje stavite čljeni facovu i pjoni...  ...
# 14  hulahopke ženske i kratke brageše, do kasno va...  ...
# 15  Te hulahopke su bile, to j bilo jedno brižno v...  ...
# 16  Ali te hulahopke su se zvale hlače. Va klami, ...  ...
# 17  Učiteljica je rekla, ovo ponavljan još jedan p...  ...
# 18  On je rekal.: Ali, ja niman plavih slač. Kakov...  ...
# 19  va krapkih, plavih bragešah i va tih pokrpanih...  ...
# 20  I ona ga je, nas je bilo puno va razredu, mord...  ...
# 21  Njemu mi bilo jasno zač on ne smi recitirat. A...  ...
# 22  Evo, tako da su dica imela problema s hrvackin...  ...
# 23  Potle, jednostavno, tako vrime pasivalo smo mi...  ...
# 24  E, sada kako je nas bilo puno, i dan dan dan d...  ...
# 25  I kada smo mi teli- ja i to ne storit ovu knji...  ...
# 26  sina. I govorin radi kurjoziteta, biš li ti pr...  ...
# 27  A što je meni- on govori klajenski, perfektno....  ...
# 28  A,.)breath). Kako je nas bila većina, nje smo ...  ...
# 29  E, navadiju san se puno besid ke se sada ne up...  ...
# 30  Vežene su za šumu, vežene su za polje, vežene ...  ...
# 31  Volin pisat poklaninski. Još manenu smišnu stv...  ...
# 32  va glavi, ga ne minjaš. Šal san va vojšku. Va ...  ...
# 33  A va klani se reče za titota. I ja san rekal z...  ...
# 34  Aš san rekav, ja za titota. Kada smo prišli na...  ...
# 35  .)laughing). To je, evo, to bi bilo od mojega ...  ...
# 36  Sada mi se j dogodilo.)breath.) pred malo vrim...  ...
# 37                 Govorin- Elenica, kako ti je bilo?  ...
# 38  na jedni priredbi. Nono, ti si mi bil jako čud...  ...
# 39  .)laughing). Ja te još n is čula govorit knjiž...  ...
# 40  Znam da se je va moj govor pomišalo puno besid...  ...
# 41  .)laughs). Bez da će čovik prijme i njihov nag...  ...
# 42  Evo, meni bi rekao Šnajdar da je čut da niku b...  ...
# 43  eh). ne glumin, govorin baš onako kako san se ...  ...
# 44  puno stvari ke- kih morda ni drugdi, recimo, v...  ...
# 45  Kada su šli va šumu, su šli va goru, gori Kada...  ...
# 46  Kada je loš čovik je gori Kada je niki šal na ...  ...
# 47  Ena besida po čet- ima četiri značenja, ka zna...  ...
# 48  je bilo, kada je bilo je bilo. Tako, jedna bes...  ...
# 49  Drukčiji je naglasak, ali ista besida je za pa...  ...
# 18    (144.44444444444443, 0, 0, 13, 9, 9)
# 19                 (15.0, 3, 0, 0, 17, 20)
# 20   (44.11764705882353, 2, 11, 2, 21, 34)
# 21    (26.08695652173913, 1, 2, 3, 20, 23)
# 22    (27.27272727272727, 4, 1, 1, 17, 22)
# 23    (9.090909090909092, 1, 1, 0, 20, 22)
# 24   (10.714285714285714, 2, 1, 0, 25, 28)
# 25    (26.08695652173913, 1, 5, 0, 17, 23)
# 26                 (40.0, 2, 4, 2, 14, 20)
# 27                 (30.0, 3, 3, 0, 14, 20)
# 28                 (25.0, 1, 3, 2, 20, 24)
# 29   (14.705882352941178, 3, 1, 1, 30, 34)
# 30    (11.11111111111111, 2, 1, 0, 24, 27)
# 31   (21.052631578947366, 0, 0, 4, 19, 19)
# 32   (23.809523809523807, 4, 0, 1, 17, 21)
# 33  (113.63636363636364, 1, 6, 18, 15, 22)
# 34    (88.23529411764706, 0, 13, 2, 4, 17)
# 35   (107.14285714285714, 0, 14, 1, 0, 14)
# 36                 (10.0, 2, 0, 0, 18, 20)
# 37                (1100.0, 1, 0, 10, 0, 1)
# 38     (122.22222222222223, 1, 8, 2, 0, 9)
# 39                 (130.0, 1, 3, 9, 6, 10)
# 40                 (45.0, 3, 4, 2, 13, 20)
# 41    (46.666666666666664, 0, 6, 1, 9, 15)
# 42   (35.714285714285715, 4, 4, 2, 20, 28)
# 43                 (20.0, 1, 2, 1, 17, 20)
# 44                 (15.0, 1, 1, 1, 18, 20)
# 45    (33.33333333333333, 0, 5, 1, 13, 18)
# 46                 (15.0, 3, 0, 0, 17, 20)
# 47    (27.77777777777778, 3, 2, 0, 13, 18)
# 48                 (25.0, 3, 3, 1, 22, 28)
# 49                  (0.0, 0, 0, 0, 18, 18)
# 50                  (0.0, 0, 0, 0, 17, 17)
# 51    (38.88888888888889, 3, 2, 2, 13, 18)
#
#                       transcription_v9_wer  \
# 0   (333.33333333333337, 3, 1, 46, 11, 15)
# 1                                      inf
# 2                 (2300.0, 0, 1, 22, 0, 1)
# 3                                      inf
# 4                     (0.0, 0, 0, 0, 1, 1)
# 5     (33.33333333333333, 0, 3, 2, 12, 15)
# 6    (105.88235294117648, 0, 17, 1, 0, 17)
# 7                  (25.0, 3, 3, 0, 18, 24)
# 8    (21.052631578947366, 0, 3, 1, 16, 19)
# 9    (26.666666666666668, 0, 0, 4, 15, 15)
# 10                (60.0, 0, 10, 2, 10, 20)
# 11   (16.666666666666664, 1, 0, 1, 11, 12)
# 12  (928.5714285714287, 0, 13, 117, 1, 14)
# 13   (14.285714285714285, 2, 0, 0, 12, 14)
# 14                  (5.0, 1, 0, 0, 19, 20)
# 15   (65.71428571428571, 2, 18, 3, 15, 35)
# 16                (104.0, 0, 25, 1, 0, 25)
# 17                 (40.0, 1, 1, 4, 13, 15)
# 18   (1333.3333333333335, 1, 4, 115, 4, 9)
# 19   (14.285714285714285, 3, 0, 0, 18, 21)
# 20   (67.64705882352942, 1, 21, 1, 12, 34)
# 21   (17.391304347826086, 0, 1, 3, 22, 23)
# 24    (53.57142857142857, 8, 4, 3, 16, 28)
# 25    (69.56521739130434, 4, 10, 2, 9, 23)
# 26    (31.57894736842105, 3, 2, 1, 14, 19)
# 27                 (45.0, 5, 3, 1, 12, 20)
# 28                 (37.5, 5, 3, 1, 16, 24)
# 29   (54.54545454545454, 10, 6, 2, 17, 33)
# 30   (23.076923076923077, 4, 1, 1, 21, 26)
# 31     (57.89473684210527, 8, 2, 1, 9, 19)
# 32                (100.0, 10, 4, 6, 6, 20)
# 33    (81.81818181818183, 4, 8, 6, 10, 22)
# 34   (135.29411764705884, 6, 3, 14, 8, 17)
# 35     (33.33333333333333, 2, 1, 1, 9, 12)
# 36                 (15.0, 1, 1, 1, 18, 20)
# 37                  (600.0, 0, 1, 5, 0, 1)
# 38     (111.11111111111111, 2, 1, 7, 6, 9)
# 39     (133.33333333333331, 3, 1, 8, 5, 9)
# 40                (105.0, 3, 10, 8, 7, 20)
# 41   (46.666666666666664, 5, 0, 2, 10, 15)
# 42    (37.93103448275862, 6, 5, 0, 18, 29)
# 43                 (60.0, 7, 3, 2, 10, 20)
# 44    (61.904761904761905, 9, 3, 1, 9, 21)
# 45    (22.22222222222222, 0, 4, 0, 14, 18)
# 46    (31.57894736842105, 3, 3, 0, 13, 19)
# 47     (55.55555555555556, 3, 6, 1, 9, 18)
# 48  (42.857142857142854, 10, 2, 0, 16, 28)
# 49   (17.647058823529413, 2, 1, 0, 14, 17)
# 50    (22.22222222222222, 3, 0, 1, 15, 18)
# 51                 (50.0, 2, 1, 6, 15, 18)
#
#                                            text_clean
# 0   pa sad moremo po naše sa se moremo prehitit i ...
# 1                                                 mhm
# 2
# 3
# 4                                                 mhm
# 5   rojen san va klani sedamnajst dvanajstiga pede...
# 6     nisan puno navadiv  tatinih besid aš je on m...
# 7   živiv san z mamu  i živiv san s staru nonu od ...
# 8   si smo govorili va klani po klanjski tako da  ...
# 9   aš je to bila za nas ena  ena čudna stvar nepo...
# 10  enu stvar iz drugiga razreda ka je za ka se je...
# 11  prvimu razredu ki je biv prijet va pionire mi ...
# 12  a glavninu pjesme je recitirav  naš najbolji u...
# 13  va bile stomanje stavite črljeni facov i pioni...
# 14  hulahopke ženske i kratke brageše do kasno va ...
# 15  te hulahopke su bile to je bilo eno brižno vri...
# 16  ali te hulahopke su se zvale hlače va klani i ...
# 17  učiteljica je rekla  ovo ponavljan još edan pu...
# 18       on je rekav  i mladen je prišav na pozornicu
# 19  va kratkih plavih bragešah i va tih pokrpanih ...
# 20  i ona da je nas je bilo puno va razredu morda ...
# 21  njemu ni bilo jasno zač on ne smi recitirat  a...
# 22  evo tako da su dica imela problema s hrvackin ...
# 23  potle  jednostavno hm kako je vrime pasivalo s...
# 24  e sada kako je nas bilo puno i dan danas su di...
# 25  i kada smo mi teli  ja i tone storit ovu knjig...
# 26  sina i govorin radi kurioziteta biš li ti priš...
# 27  aš to je meni on govori klanjski  perfektno i ...
# 28   kako je nas bila većina nje smo navadili po k...
# 29  e! navadiv san se puno besid ke se sada ne upo...
# 30  vežene su za šumu vežene su za polje vežene su...
# 31  volin pisat po klanjski  još man enu enu smišn...
# 32  va glavi ga ne minjaš šav san va vojsku va voj...
# 33  a va klani se reče  i ja san rekav   i si su m...
# 34  aš san rekav ja  kada smo prišli na glavnu na ...
# 35   to je  evo to bilo od mojiga klanjskiga i  sa...
# 36  sada mi se j' dogodilo pred malo vrimena mi se...
# 37                                            govorin
# 38           na eni priredbi  ti si mi biv jako čudan
# 39      govorin dobro je pa da san ji biv jako čudan
# 40  znan da se je va moj govor pomišalo puno besid...
# 41   bez da će čovik prime i njihov naglasak prime...
# 42  evo m m m meni bi rekav šnajdar da je čut da d...
# 43    ne glumin govorin baš onako kako  kako san s...
# 44  puno stvari ke ke kih morda ni drugdi recimo v...
# 45  kada su šli va šumu  su šli va goru  gora gori...
# 46  kada je loš čovik je gori vavik je gori kada j...
# 47  ena besida po čet ma četiri značenja kaj ja zn...
# 48  je bilo kada je bilo je bilo tako ena besida m...
# 49  drukčiji je naglasak ali ista besida je za par...
# 50  puno  puno jeziki ljudi su od sih nič prijeli ...
# 51  si rečeju poneštra samo klanjci rečeju okno aš...
#
# [52 rows x 29 columns]

# %%
df['text_clean'].values
# Out:
# array(['pa sad moremo po naše sa se moremo prehitit i počet dakle  kadi ste rojeni',
#        'mhm', '', '', 'mhm',
#        'rojen san va klani sedamnajst dvanajstiga pedesprve  mama mi je klanjica tata   prišav iz sežane',
#        '  nisan puno navadiv  tatinih besid aš je on mlad umrv se kaj san navadiv san navadiv klanjski',
#        'živiv san z mamu  i živiv san s staru nonu od njih san se navadiv govorit i  va vrime kada san ja biv dica',
#        'si smo govorili va klani po klanjski tako da  da kada smo krenili va školu smo imeli problema s književnin',
#        'aš je to bila za nas ena  ena čudna stvar nepoznata i  ja van moran reć',
#        'enu stvar iz drugiga razreda ka je za ka se je samo nan mogla dogodit morali smo  vezat  facole črljene',
#        'prvimu razredu ki je biv prijet va pionire mi smo morali recitirat pjesmu',
#        'a glavninu pjesme je recitirav  naš najbolji učenik i učiteljica nan je ovako rekla',
#        'va bile stomanje stavite črljeni facov i pionirsku baretu mi muška dica smo nosili',
#        'hulahopke ženske i kratke brageše do kasno va jesen isto tako kada je proliće prišlo mi smo bili va hulahopkah',
#        'te hulahopke su bile to je bilo eno brižno vrime kada ni bilo ča kupit te hulahopke su bile zakrpane s tuliko konca da više nisi poznav od čeza  od čeza su bile s same hulahopke storene',
#        'ali te hulahopke su se zvale hlače va klani i sada starije ženke kada se obujeju va hulahopke se obujeju va hlače ne va hulahopke',
#        'učiteljica je rekla  ovo ponavljan još edan put a ta ki je morav glavnu recitaciju reć',
#        'on je rekav  i mladen je prišav na pozornicu',
#        'va kratkih plavih bragešah i va tih pokrpanih hlačah i kada ga je vidila učiteljica ni ga mogla pustit da recitira',
#        'i ona da je nas je bilo puno va razredu morda pedeset ona ga je porinila odzada da ga ne vide ljudi a ena divojčica ka isto znala recitirat ona je misto njega recitirala',
#        'njemu ni bilo jasno zač on ne smi recitirat  a on je prišav po klanjski va hlačah on je prišav va hlačah  pokrpanih',
#        'evo tako da su dica imela problema s hrvackin zapravo onda je biv to nametnjen srpskohrvacki imeli smo problema va školi i',
#        'potle  jednostavno hm kako je vrime pasivalo smo mi prijeli jezik i s nami su bila dica od oficiri dica od milicjoneri',
#        'e sada kako je nas bilo puno i dan danas su dica od tih oficiri ka žive nigdi ća iz klane ki govore morda bolje klanjski nego mi',
#        'i kada smo mi teli  ja i tone storit ovu knjigu od ovo od ovih pjesam klanjskih san ja zvav od eniga milicjonera',
#        'sina i govorin radi kurioziteta biš li ti prišav biš li prišav s nami na na tu promociju da ti  govoriš klanjski',
#        'aš to je meni on govori klanjski  perfektno i on mi je biv obećav biv je sprečen ni mogav prit',
#        ' kako je nas bila većina nje smo navadili po klanjski govorit tu dicu ka su bila tuja i puno njih je govorilo po klanjski',
#        'e! navadiv san se puno besid ke se sada ne upotrebljavaju gotovo e i ne moreju se ni upotrebljavat aš su te beside vežene za za on za dilo ko se je onda dilalo',
#        'vežene su za šumu vežene su za polje vežene su za bilo ku stvar ka se više ne dila onda ja san provav malo od tih besid zapisat',
#        'volin pisat po klanjski  još man enu enu smišnu stvar ku moran reć kada ti ostane tvoj jezik va va',
#        'va glavi ga ne minjaš šav san va vojsku va vojski smo polagali  zakletvu va zakletvi edan dio zakletve je biv',
#        'a va klani se reče  i ja san rekav   i si su mi se to na provah si su mi se smijali',
#        'aš san rekav ja  kada smo prišli na glavnu na na glavnu zakletvu samo ja san rekav ',
#        ' to je  evo to bilo od mojiga klanjskiga i  sada za za govorit književno',
#        "sada mi se j' dogodilo pred malo vrimena mi se je dogodilo da mi je  moja unuka elena rekla ovako",
#        'govorin', 'na eni priredbi  ti si mi biv jako čudan',
#        '  govorin dobro je pa da san ji biv jako čudan ',
#        'znan da se je va moj govor pomišalo puno besid puno besid zato aš san dilav puno lit va opatiji',
#        ' bez da će čovik prime i njihov naglasak prime  naglasak od književniga prime naglasak od',
#        'evo m m m meni bi rekav šnajdar da je čut da da niku besidu rečen kot kaj rečeju na matulji naš ja ne primjetin ali  verujen da je tako',
#        '  ne glumin govorin baš onako kako  kako san se navadiv verujen da grešin va našimu va našimu klanjskimu jeziku je puno',
#        'puno stvari ke ke kih morda ni drugdi recimo va klani se reče  enu besidu se upotrebi i za četiri stvari',
#        'kada su šli va šumu  su šli va goru  gora gori kada su šli  prema šumi su šli gori',
#        'kada je loš čovik je gori vavik je gori kada je niki šav na vrh kiše je šav gori tako ',
#        'ena besida po čet ma četiri značenja kaj ja znan nike su  va klani je bilo kada biliš',
#        'je bilo kada je bilo je bilo tako ena besida ma par značenji morda je to i i drugdi ja nis abadav ali je ali ovo vidin da je',
#        'drukčiji je naglasak ali ista besida je za par stvari kako je va klani  pasalo puno  puno držav',
#        'puno  puno jeziki ljudi su od sih nič prijeli puno su prijeli od slovenci aš smo tu blizu',
#        'si rečeju poneštra samo klanjci rečeju okno aš je slovenski je okno je  ali va klani je okno'],
#       dtype=object)
