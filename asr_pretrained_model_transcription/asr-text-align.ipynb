# %%
# get result from models: full length audio as input

# classla
text_classla = 'dobro onda moramo započet s obzirom da sam i ja govornikhna materinskoga idioma onda ćemo govorit ćokuratko da majte pa za početak moraš nam reći nešto u kratko seb be kadeciji rođena kade si se zgojila i tako nes očate domisija na ljetinstvo znači rodilac sam se u tervižu jedan mestu srednjovjekovning gradiću blizu pazina živila sam za mah maniskajčon znonikima iz brotoni sestron za djetinjstvom vežu jakolepe uspomene je najviše bezbližna igra a sa svojim susedima koji su mi dan da nas su neki ustali preteli najlepči e iz jetinstva su razno razne zn igre vezane za ne znani gralis mose npr restorana pa smo si stavili van sve kalotine i jenakalotina maloveća na nje bila kako miza a sve okolo su bili karege onda smo se igrali zmuž kema smo se s obzirom da nije bilo još prevet igrečka tječajima a to smo se grali s muškema smo se grali sveturicama u sablonu najveć smo delali kućice na drevu a na večer bimo ne znam se grali skrivača ili plan grada pa smo se i štali puno dišpe etax smo delali dobro da ni smo uveđane strićje napravili tako da se mo neke pute onke  žali staviti špah po sred česte pa salako kibi moga i rovinad meni hvala bogu za razliku od današnje dice koja nmaju u biti najlepše ne je bilo toča smo imali velik veliku slobod slobodu da nas niki ni kontrolira znali smo da ako nešto u fabrikamada će nas još doma spraskatozgor ali mismo tek to znali to nas ni brigalo s teši smo se razvili puno slobodnije i frši bolje smo pensale i foša sad znamo snag malo bolje onda čaja znam udjetinstvu isa to tako nje bilo jako lepo kantat uzjenega našega orguljas a koji nas je ženske okupi oko crekve tako reći pa s mona nje ustvari hobi ili javajkrećin izvan nastavene aktivnosti su name bile pojć hmaša imolit krunicu u 5e me msecu i u 6 ni 10 ni pole obavezno kantana maša to je to se i '

# classla-lg
text_classla_lg = 'dobro onda moramo započet s obzirom da sam ja govornik materinskoga edioma onda ćemo govorit ćehulatko do maćepa za početak moraš nam reći nešto ukratko o sebi e kadeci rodjena kades se zgonjila i tako nešto počate do misija na djetinstvo znači rodilas sam se u tervižu jena mestu srednjobjekovnin radiću blizu pazina živjiela samm zama amonisaćon znonićima iz bratoni sestrono za djetinstvo oome vežu jako lepe uspomene najviše bezbrižna igra a sa svojim susjedima koji su mi dan danas neki ustali preteli najlepći iz jedinstva su razno razne e zam igre vezane za ne zna nigls mo se na primjer restorana pa smo si stavili van sve kalotine i je na kalotina malo većana nje bila kako miza a sve okolo su bili karegem onda smo se igrali s mus škama smo se s obzirom da nije bilo jaš prevetih grečka tječajima to smo se igrali s muškima smo se i grali z veturicoama u sablonu najveć smo delali kutice na drevu a na večer bimo ne znam segra li skrivača ili plan grada pa smo se i šćjali puno dišpe etak smo djelali dobro da nismo većene strite napravili tako da e mo neke pute onaevo žali staviti špa posred česte pa salakoki bi moga rovinat meni hvala bogu za razliku od današnje djice koja nimaj u biti najlepće nim je bilo to čda smo imali veliku slobou du slobodu da nas niki ni kontrolira zna li smo dako nešto u fabrikama da će nas još doma spraskat odzgor ali mi smo to znali i to nas ni brigalo stešli smo se razvili puno slobodnije i fri bolje smo pensale i fašisac sad znamo snać malo boje onda čajaznanudjetinjstvu is sto tako neni je bilo jako lepo kantat uzije nega našega orguljaš a koji nas je ženske ukupio oko crekve tako reći pa sa mo nanje ustvari hobi ili javaj krećem izvan asne aktivnosti s nam bile poića hmaše imoli t krunicu u petrnme jesecu i u šeste ni u 1 n  pola obavezno kamtana maša to je to če '

# nvdia
text_nvdia = 'dobro za poto u kratko znači rodila sam se u tervižu je na mjestu srednjobjekovnom gradigu blizu pazinam živjela sam za mamni s jađan znonikima i s bratom i sestrom za djetinjstvo oni me vežu jako lejepe uspomene najviše bezbrižna igra sa svojim susjedima koji su mi dan danas neki u stali i preteli najljepše iz jetinstva su raznozne ne znam igre vezane za ne znam igrali smo se na primjer restorana pa smo si stavili van sve kalutine i jedna kalutina malo velja nam je bila kako miza a sve okolo su bili karege onda smo se igrali s muškama smo se s obzirom da nije bilo još prevelikih igračka tječajima to smo se igralie s muškama smo se igrali s veturicama u sablonu najveć smo delali kutice na drevu a navečer bimo ne znam se igrali skrivača ili plan grada pa smo se išljali puno dišpetak smo delali dobro da nismo veđene strike napravili tako da smo neki put anteu žali staviti pah po sred šeste pa bi se lako kibimoga i rove nat meni hvala bogu za razliku do našnje dice koja u biti najlapše nam je bilo toča smo imali veliku veliku slobodu slobodu da nas niki ni kontrolira znali smo da ako nešto u fabrikamo da će nas još doma spraskati od gor ali mismo to znali to nas ni briga lostišli smo se razvili puno puno slobodnije i foši bolje smo pensali i faši sad znamo snaći malo bolje onda ča ja znam u djetinjstvu isto tako nam je bilo jako lepo kantat uz jenega našega orguljaša koji nas je žensski okupio oko crekve tako reći pa smo na ustvari hobi ili javaj krećem izvan na stavne aktivnosti su nam bile pojc hmaša i molit krunicu u petm mjesecu i u šest ni u deseteni pole obavezno kapantana maša to je to ča sam ti i'

# whisper
text_whisper = 'Dobro, onda moremo zapocet. Sobrila, onda se njagovornik matrenjskih da je dioma, onda ćemo govori čekolad kodoma tepa. Zapocetak mori na reći nešto u kratko sebe, kadesi rodjena, kadesi se zgodila i tako neštočate domisija na dijetejnjstvo. Načirodila sam se u tervižu, je ne meisto, sredni objekovne in gradicju, blizupazina. Živila sam za maman istjacion, znonitima izbratuni sejstron. Zdje tinsom, je veđu jako lepe uspomene, najviše bezbižina igra sa svojnju su sedima, koji su mi dan da nas neki ustali preteli. Najlepče izjetinjstva su razno razne, ne znam igre vezane za, ne znam, i grali smo se na primjer restauranta, pasmo si stavili van sve kalotine. I jednako ljutina malo veća na njebila kako mi za, a sve okolo su bili kao regem, onda smo se igrali zmuške, ma smo se sobzru on da njih bila jaš priveći igrački, ki je čajima to smo se igrali. Zmuške, ma smo se igrali zveturica, ma usablonu. Najveć smo delali kutice na drevu, a na veća bi mo ne znam, se igrali skrivača, ili plan grada, pa smo se i štjali. Puno di špetak smo delali, dobro da nismo veća ne strite napravili, tako da smo neke pute, a on te užali staviti špa, po sred ćeste pa bi se lako ki bi moga i rovenat menihvala bogu. Zrazliko da našnje dice, koja nime, u biti nelepćene njih bylo točas moj mali, veliko veliku slobodu, slobodu, da na sniki ni kontrolira, znali smo da, kubu ne što u fabrikam, da ja naš još doma spraska to zgor, ali mismo te to znali, to nas njiberi galosti, smo se razvili puno slobodnje i forši bolje, smo pensali i for što se sad znamo snak malo boje. Onda čaja znam, nudje tinstvistu, tako ne njibelo jako lepokantat, uz je nega našega orgu ljašako je nas jev ženske, u kupijo, ako crekve, tako reć, pa smo na nije u svari chobi, ili ja vaik rećeni zvenan stave, neakljivnosti su nam byle pojtje, mašaj molid krunicu, u 5 mesetu i u 6, i u 10. pole, oba vezno kam dana maša. To, to, to, to.'
# whisper has time info

# correct text
text_manual = 'dobro onda moremo eh započet s obziron da san i ja govornik materinskega idioma onda ćemo govorit ću provat po domaće pa za početak moreš nan eh reć nešto u kratko o sebe kade si rođena kade si kade si se zgojila i tako nešto ča te domišja na djetinjstvo eh znači rodila san se u Trvižu eh jenen eh mestu srednjovjekovnen gradiću eh blizu Pazina eh živila san z mamon i z ćaćon z nonićima i z braton i sestron eh djet za eh djetinstvo me vežu jako lepe uspomene eh najviše mmm bezbrižna igra sa svojin susedima eh koji su mi eh dan danas neki ustali i preteli eh najlepče iz djetinjstva eh su raznorazne eh n ne znan igre vezane za ne znan igrali smo se na primjer eh restorana pa smo si stavili mmm van sve eh kalotine i jena kalotina malo veća nan je bila kako miza a sve okolo su bili eh karege eh onda smo se igrali eh z muškema smo se s obziron da ni bilo još preveć igračkah ki je ča ima to smo se igrali z muškema smo se igrali z veturicama u sablonu eh najveć smo delali kućice na drevu eh a navečer bimo eh ne znan se igrali eh skrivača ili eh plan plan grada pa smo se išćali puno dišpetah smo delali dobro da nismo veće nesriće napravili tako da smo neke pute anke užali stavit špah po sred česte pa bi se lako ki bi moga i rovinat ma ni hvala bogu za razliku od današnje dice eh koja nimaj/ u u u biti eh najlepče nan je bilo to ča smo imali veliku veliku slobodu slobodu eh da nas niki ni kontrolira eh znali smo da ako nešto ufabrikamo da će nas još doma spraskat odozgor eh ali mi smo tek to znali to nas ni brigalo steši smo se razvili puno puno slobodniji forši bolje smo pensali forši se sad znamo snać malo boje onda ča ja znan u djetinjstvu isto tako nan je bilo jako lepo kantat uz jenega našega orguljaša koji nas je ženske okupi oko mmm oko crekve tako reć pa smo nan je u stvari hobi ili ja vajk rečen izvannastavne aktivnosti su nan bile poć eh h maše i molit krunitsu eh eh u peten mesecu i u šesten i u deseten i pole obavezno mmm kantana maša to je to je to ča se ti'

# %% [markdown]
# # text alignment

# %%
# text to audio force alignmment

from aeneas.executetask import ExecuteTask
from aeneas.task import Task

models = ['classla', 'classla_lg', 'nvdia']
# create Task object
config_string = u"task_language=hrv|is_text_type=plain|os_task_file_format=json"
task = Task(config_string=config_string)
task.audio_file_path_absolute = u"/Users/irisz/downloads/2023_ELIC/align/audio/ckm001-2022-01-16-Trviž_01.wav"
task.text_file_path_absolute = u"/Users/irisz/downloads/2023_ELIC/align/text/" + models[2]  + ".txt"
task.sync_map_file_path_absolute = u"/Users/irisz/downloads/2023_ELIC/align/" + models[2]  + ".json"

# process Task
ExecuteTask(task).execute()

# output sync map to file
task.output_sync_map_file()
# Out:
# '/Users/irisz/downloads/2023_ELIC/align/nvdia.json'

# %%
# text to text fuzzy alignment

# %%
import json
 
# Opening JSON file
with open('/Users/irisz/downloads/2023_ELIC/align/' + models[2]  + '.json') as json_file:
    data = json.load(json_file)

# %%
len(data['fragments'])
# Out:
# 312

# %%
dic_result = data['fragments']
dic_result[0]
# Out:
# {'begin': '0.000',
#  'children': [],
#  'end': '1.200',
#  'id': 'f000001',
#  'language': 'hrv',
#  'lines': ['dobro']}

# %%
lines = []
lines_head = ['File type = "ooTextFile"',
'Object class = "TextGrid"', '']
xmin_all = 'xmin = ' + str(dic_result[0]['begin'])
xmax_all = 'xmax = ' + str(dic_result[-1]['end'])

tier_info = ['tiers? <exists>', 
'size = 1', 
'item []:',
'    item [1]:',
'        class = "IntervalTier"', 
'        name = "segments_text"'             
]

#xmin
#xmax
interval = 'intervals: size = ' + str(len(dic_result))

sec_all = []
for i in range(len(dic_result)):
    curr_sec = dic_result[i]
    interval_curr = 'intervals [' + str(i + 1) + ']:'
    xmin = 'xmin = ' + str(curr_sec['begin'])
    xmax = 'xmax = ' + str(curr_sec['end'])
    text = 'text = "' + curr_sec['lines'][0] + '"'
    sec_all = sec_all + [interval_curr, xmin, xmax, text]

lines = lines_head + [xmin_all,xmax_all] + tier_info + [xmin_all,xmax_all,interval] + sec_all

# %%
lines
# Out:
# ['File type = "ooTextFile"',
#  'Object class = "TextGrid"',
#  '',
#  'xmin = 0.000',
#  'xmax = 175.000',
#  'tiers? <exists>',
#  'size = 1',
#  'item []:',
#  '    item [1]:',
#  '        class = "IntervalTier"',
#  '        name = "segments_text"',
#  'xmin = 0.000',
#  'xmax = 175.000',
#  'intervals: size = 312',
#  'intervals [1]:',
#  'xmin = 0.000',
#  'xmax = 1.200',
#  'text = "dobro"',
#  'intervals [2]:',
#  'xmin = 1.200',
#  'xmax = 1.600',
#  'text = "za"',
#  'intervals [3]:',
#  'xmin = 1.600',
#  'xmax = 1.960',
#  'text = "poto"',
#  'intervals [4]:',
#  'xmin = 1.960',
#  'xmax = 2.040',
#  'text = "u"',
#  'intervals [5]:',
#  'xmin = 2.040',
#  'xmax = 3.240',
#  'text = "kratko"',
#  'intervals [6]:',
#  'xmin = 3.240',
#  'xmax = 3.600',
#  'text = "znači"',
#  'intervals [7]:',
#  'xmin = 3.600',
#  'xmax = 4.280',
#  'text = "rodila"',
#  'intervals [8]:',
#  'xmin = 4.280',
#  'xmax = 4.880',
#  'text = "sam"',
#  'intervals [9]:',
#  'xmin = 4.880',
# ...

# %%
with open('/Users/irisz/downloads/2023_ELIC/align/' + models[2]  + '.TextGrid', 'w') as f:
    for line in lines:
        f.write(f"{line}\n")

# %%
from Bio import pairwise2
from Bio.pairwise2 import format_alignment


string1 = 'my channel is youtube dot com slash example and then I also do live streaming on twitch.'
string2 = 'my channel is youtube.com/example and then I also do livestreaming on twitch.'

alignments = pairwise2.align.globalxx(string1.split(), 
                                      string2.split(),
                                      gap_char=['-']
                                     )
# Out:
# /Users/irisz/opt/miniconda3/lib/python3.9/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
string1 = text_manual
string2 = text_classla


alignments = pairwise2.align.globalxx(string1.split(), 
                                      string2.split(),
                                      gap_char=['-']
                                     )

# %%
alignments
# Out:
# [Alignment(seqA=['dobro', 'onda', 'moremo', 'eh', '-', 'započet', 's', 'obziron', '-', 'da', 'san', '-', 'i', 'ja', 'govornik', 'materinskega', '-', '-', 'idioma', 'onda', 'ćemo', 'govorit', 'ću', 'provat', 'po', 'domaće', '-', '-', '-', 'pa', 'za', 'početak', 'moreš', 'nan', 'eh', 'reć', '-', '-', '-', 'nešto', 'u', 'kratko', 'o', 'sebe', 'kade', 'si', '-', '-', '-', 'rođena', 'kade', 'si', 'kade', 'si', 'se', 'zgojila', 'i', 'tako', 'nešto', 'ča', 'te', 'domišja', '-', '-', '-', 'na', 'djetinjstvo', 'eh', '-', 'znači', 'rodila', 'san', '-', '-', 'se', 'u', 'Trvižu', 'eh', 'jenen', 'eh', '-', '-', 'mestu', 'srednjovjekovnen', '-', 'gradiću', 'eh', 'blizu', 'Pazina', 'eh', '-', 'živila', 'san', 'z', 'mamon', 'i', 'z', 'ćaćon', 'z', 'nonićima', 'i', 'z', 'braton', 'i', '-', '-', '-', '-', '-', '-', '-', 'sestron', 'eh', 'djet', 'za', 'eh', 'djetinstvo', 'me', '-', 'vežu', 'jako', 'lepe', '-', 'uspomene', 'eh', '-', 'najviše', 'mmm', 'bezbrižna', '-', 'igra', '-', 'sa', 'svojin', '-', 
# ...

# %%
import pandas as pd
df = pd.DataFrame(columns = ['manual', 'classla'])
df['manual'] = alignments[0].seqA
df['classla'] = alignments[0].seqB
df
# Out:
#      manual classla
# 0     dobro   dobro
# 1      onda    onda
# 2    moremo       -
# 3        eh       -
# 4         -  moramo
# ..      ...     ...
# 539      to      to
# 540      ča       -
# 541      se      se
# 542      ti       -
# 543       -       i
#
# [544 rows x 2 columns]

# %%
df.head(30)
# Out:
#           manual       classla
# 0          dobro         dobro
# 1           onda          onda
# 2         moremo             -
# 3             eh             -
# 4              -        moramo
# 5        započet       započet
# 6              s             s
# 7        obziron             -
# 8              -       obzirom
# 9             da            da
# 10           san             -
# 11             -           sam
# 12             i             i
# 13            ja            ja
# 14      govornik             -
# 15  materinskega             -
# 16             -   govornikhna
# 17             -  materinskoga
# 18        idioma        idioma
# 19          onda          onda
# 20          ćemo          ćemo
# 21       govorit       govorit
# 22            ću             -
# 23        provat             -
# 24            po             -
# 25        domaće             -
# 26             -     ćokuratko
# 27             -            da
# 28             -         majte
# ...

# %%
# fuzzing word matching

from thefuzz import fuzz

name = "Kurtis Pykes"
full_name = "Kurtis K D Pykes"

print(f"Similarity score: {fuzz.ratio(name, full_name)}")
# Out:
# Similarity score: 86

# %%
t1 = 'moremo'
t2 = 'moramo'
fuzz.ratio(t1, t2)
# Out:
# 83

# %%
t1 = 'eh'
t2 = 'moramo'
fuzz.ratio(t1, t2)
# Out:
# 0

# %%
t1 = 'govornik'
t2 = 'govornikhna'
fuzz.ratio(t1, t2)
# Out:
# 84

# %%
t1 = 'materinskega'
t2 = 'materinskoga'
fuzz.ratio(t1, t2)
# Out:
# 92

# %%
'a' == 'a'
# Out:
# True

# %%
def get_matched(t1, t2):
    #print (t1, t2)
    if t1 == t2:
            return 1
    else:
        return 0
df['match'] = df.apply(lambda x:get_matched(x.manual, x.classla), axis = 1)

# %%
def get_unmatched_cand(match_list, idx):
    cand = []
    idx_org = idx
    if match_list[idx] == 1:
        return [idx]
    else:
        while match_list[idx] != 1 and idx > 0:
            cand.append(idx)
            idx = idx - 1 # before
        idx = idx_org
        while match_list[idx] != 1 and idx < len(match_list) -1:
            cand.append(idx)
            idx = idx + 1 # after
        return list(set(cand))
get_unmatched_cand(df['match'].tolist(), idx = 3)
# Out:
# [2, 3, 4]

# %%
df['idx'] = df.index

# %%
df['match_cand'] = df.apply(lambda x: get_unmatched_cand(df['match'].tolist(), x.idx), axis = 1)

# %%
def word_match_score(t1, t2):
    if t1 == '-' or t2 == '-':
        return 0
    else:
        score = fuzz.ratio(t1, t2)
        return score
def get_can_score(idx,match_cand):
    if len(match_cand) == 1:
        return [100]
    score_all = []
    for cand in match_cand:
        t1 = df['manual'][idx]
        t2 = df['classla'][cand]
        score = word_match_score(t1, t2)
        score_all.append(score)
    return score_all

# %%
df['match_cand_score'] = df.apply(lambda x: get_can_score(x.idx, x.match_cand), axis = 1)

# %%
import numpy as np
def get_fuzzy_cand(match_cand, match_cand_score):
    max_cand = np.max(match_cand_score)
    if max_cand > 60:
        # fuzzy matched
        max_cand_id = match_cand[match_cand_score.index(max_cand)]
        #print (max_cand_id)
        word = df['classla'][max_cand_id]
        return word, max_cand
    else:
        return '-', 0

# %%
df['classla_fuzzy'] = df.apply(lambda x: get_fuzzy_cand(x.match_cand, x.match_cand_score)[0], axis = 1)
df['classla_fuzzy_score'] = df.apply(lambda x: get_fuzzy_cand(x.match_cand, x.match_cand_score)[1], axis = 1)

# %%
df.head(30)
# Out:
#           manual       classla  match  idx                    match_cand  \
# 0          dobro         dobro      1    0                           [0]
# 1           onda          onda      1    1                           [1]
# 2         moremo             -      0    2                     [2, 3, 4]
# 3             eh             -      0    3                     [2, 3, 4]
# 4              -        moramo      0    4                     [2, 3, 4]
# 5        započet       započet      1    5                           [5]
# 6              s             s      1    6                           [6]
# 7        obziron             -      0    7                        [8, 7]
# 8              -       obzirom      0    8                        [8, 7]
# 9             da            da      1    9                           [9]
# 10           san             -      0   10                      [10, 11]
# 11             -           sam      0   11                      [10, 11]
# ...

# %%
df[df['manual']!= '-'].head(30)
# Out:
#           manual  classla  match  idx                    match_cand  \
# 0          dobro    dobro      1    0                           [0]
# 1           onda     onda      1    1                           [1]
# 2         moremo        -      0    2                     [2, 3, 4]
# 3             eh        -      0    3                     [2, 3, 4]
# 5        započet  započet      1    5                           [5]
# 6              s        s      1    6                           [6]
# 7        obziron        -      0    7                        [8, 7]
# 9             da       da      1    9                           [9]
# 10           san        -      0   10                      [10, 11]
# 12             i        i      1   12                          [12]
# 13            ja       ja      1   13                          [13]
# 14      govornik        -      0   14              [16, 17, 14, 15]
# 15  materinskega        -      0   15              [16, 17, 14, 15]
# ...

# %%
df_match = df[df['manual']!= '-']
df_match = df_match[['manual', 'classla_fuzzy','classla_fuzzy_score' ]]
df_match.to_csv('/Users/irisz/downloads/2023_ELIC/align/classla_fuzzy_align.csv')

# %%
len(df_match)
# Out:
# 407

# %%
## get textgrid for fuzzy matching result

## get time info dataframe from textgrid
import re
import pandas as pd
import numpy as np



def get_audio_df(textgrid_dir):
    
    with open(textgrid_dir, 'r') as file:
        lines = [line.rstrip() for line in file]
       
    text_list = []
    xmin_list = []
    xmax_list = []
    interval_list = []
    for line in lines[14:]:  #informations needed begin on the 9th lines
        if 'text =' in line:
            line = line.split('"')[1]
            if line != "":
                text_list.append(line)
                #print (len(text_list), len(xmin_list), len(xmax_list), len(interval_list), line, interval_list[-2:])
            else:
                xmin_list = xmin_list[:-1]
                xmax_list = xmax_list[:-1]
                interval_list = interval_list[:-1]
        if 'xmin' in line:
            time_min = line.split('=')[1].strip(' ')
            xmin_list.append(time_min)
        if 'xmax' in line:
            time_max = line.split('=')[1].strip(' ')
            xmax_list.append(time_max)
        if 'intervals [' in line:
            interval = line.split('[')[1].strip(']:')
            interval_list.append(interval)
        if 'intervals: size' in line:
            xmin_list = xmin_list[:-1]
            xmax_list = xmax_list[:-1]
    xmin_list = [float(item) for item in xmin_list]
    xmax_list = [float(item) for item in xmax_list]
    interval_list = [int(item) for item in interval_list]

    df = pd.DataFrame()
    df['text'] = text_list
    df['xmin'] = xmin_list
    df['xmax'] = xmax_list
    df['interval'] = interval_list
    df['tier'] = get_interval(df['interval'].tolist())
    df['start'] = df['xmin'].apply(lambda x: int(np.floor(x*16000)))
    df['end'] = df['xmax'].apply(lambda x: int(np.ceil(x*16000)))
    return df

def get_interval(time_list):
    interval_all = []
    interval_curr = 1
    for i in range(len(time_list)):
        if i == 0:
            interval_all.append(1)
        else:
            if time_list[i] > time_list[i - 1]:
                interval_all.append(interval_curr)
                continue
            else:
                interval_curr = interval_curr + 1
                interval_all.append(interval_curr)
    return interval_all

# %%
textgrid_dir = '/Users/irisz/downloads/2023_ELIC/Croatian_annotated/ckm001-2022-01-16-Trviž/ckm001-Trviž test data for speech to text/ckm001-2022-01-16-Trviž_01.TextGrid'

df_time = get_audio_df(textgrid_dir)
df_time
# Out:
#                                text        xmin        xmax  interval  tier  \
# 0                            Dobro.    0.155012    0.456584         2     1
# 1                  ((noise, smack))    0.456584    1.659126         3     1
# 2           Onda moremo eh započet.    1.659126    4.068000         4     1
# 3                ((paper rustling))    4.068000    6.757714         5     1
# 4    S obziron da san i ja govornik    6.757714    8.268000         6     1
# ..                              ...         ...         ...       ...   ...
# 489                              je  173.966988  174.032100       414     4
# 490                              to  174.032100  174.202306       415     4
# 491                              ča  174.358361  174.650000       417     4
# 492                              se  174.650000  174.793584       418     4
# 493                              ti  174.793584  174.960000       419     4
#
#        start      end
# 0       2480     7306
# ...

# %%
df_word = df_time[df_time['tier'].isin([2,4])]
df_word
# Out:
#         text        xmin        xmax  interval  tier    start      end
# 16     dobro    0.154668    0.456584         2     2     2474     7306
# 17      onda    1.659126    2.020000         4     2    26546    32320
# 18    moremo    2.020000    2.629858         5     2    32320    42078
# 19        eh    2.629858    3.070000         6     2    42077    49120
# 20   započet    3.210000    4.067719         8     2    51360    65084
# ..       ...         ...         ...       ...   ...      ...      ...
# 489       je  173.966988  174.032100       414     4  2783471  2784514
# 490       to  174.032100  174.202306       415     4  2784513  2787237
# 491       ča  174.358361  174.650000       417     4  2789733  2794400
# 492       se  174.650000  174.793584       418     4  2794400  2796698
# 493       ti  174.793584  174.960000       419     4  2796697  2799360
#
# [407 rows x 7 columns]

# %%
df_word['classla_fuzzy'] = df_match['classla_fuzzy'].tolist()
df_word['classla_fuzzy_score'] = df_match['classla_fuzzy_score'].tolist()
# Out:
# <ipython-input-152-ffd4f113d306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word['classla_fuzzy'] = df_match['classla_fuzzy'].tolist()
# <ipython-input-152-ffd4f113d306>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word['classla_fuzzy_score'] = df_match['classla_fuzzy_score'].tolist()

# %%
df_word
# Out:
#         text        xmin        xmax  interval  tier    start      end  \
# 16     dobro    0.154668    0.456584         2     2     2474     7306
# 17      onda    1.659126    2.020000         4     2    26546    32320
# 18    moremo    2.020000    2.629858         5     2    32320    42078
# 19        eh    2.629858    3.070000         6     2    42077    49120
# 20   započet    3.210000    4.067719         8     2    51360    65084
# ..       ...         ...         ...       ...   ...      ...      ...
# 489       je  173.966988  174.032100       414     4  2783471  2784514
# 490       to  174.032100  174.202306       415     4  2784513  2787237
# 491       ča  174.358361  174.650000       417     4  2789733  2794400
# 492       se  174.650000  174.793584       418     4  2794400  2796698
# 493       ti  174.793584  174.960000       419     4  2796697  2799360
#
#     classla_fuzzy  classla_fuzzy_score
# 16          dobro                  100
# ...

# %%
# generate textgrid

# %%
# wer

from jiwer import wer

reference = "hello world"
hypothesis = "hello duck"

error = wer(reference, hypothesis)
error
# Out:
# 0.5

# %%
error = wer(text_manual, text_classla)
error
# Out:
# 0.5307125307125307
